# %%
print ("hello world")
# Out:
# hello world

# %%
print (1+1)
print (2*2)
print (3/2)
# Out:
# 2
# 4
# 1.5

# %%
name = "Martin"
age = 20

print (name)
print (age)
# Out:
# Martin
# 20

# %%
for i in range(5):
    print (i+1)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
x = 5

if x > 5:
    print ("x is greater than 5")
else:
    print ("x is less than or equal to 5")
# Out:
# x is less than or equal to 5
