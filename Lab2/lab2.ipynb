# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns

# %%
df = pd.read_csv('https://raw.githubusercontent.com/DAVE3625/Dave3625-2026/refs/heads/main/Lab2/data/stud.csv', index_col=0)

df.head()
# Out:
#            Age              email hrsStudy  FinalGrade
# StudentID
# 47412       20  s47412@oslomet.no        5        46.0
# 15077       22  s15077@oslomet.no        0        65.0
# 15467       27  s15467@oslomet.no        1        26.0
# 17907       21  s17907@oslomet.no        6        68.0
# 13352      333  s13352@oslomet.no        4        34.0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 50 entries, 47412 to 28895
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Age         49 non-null     str
#  1   email       50 non-null     str
#  2   hrsStudy    49 non-null     str
#  3   FinalGrade  49 non-null     float64
# dtypes: float64(1), str(3)
# memory usage: 2.0 KB
